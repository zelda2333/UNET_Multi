# %%
cd /content/drive/MyDrive/Colab Notebooks/UNET_Multi
# Out:
# /content/drive/MyDrive/Colab Notebooks/UNET_Multi

# %%
# !python U-Net_Training.py
# Out:
# 2021-02-04 09:54:44.098789: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ------------------------------
# Loading and pre-processing train data...
# ------------------------------
# ------------------------------
# Loading train images...
# ------------------------------
# ------------------------------
# Loading train labels...
# ------------------------------
# train_x size:  (88, 3, 256, 256)
# train_y size:  (88, 256, 256, 3)
# ------------------------------
# Creating and compiling model...
# ------------------------------
# 2021-02-04 09:56:15.465827: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-04 09:56:15.467046: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python U-Net_Predict.py
# Out:
# 2021-02-04 10:06:51.699118: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ------------------------------
# Loading model and weights...
# ------------------------------
# 2021-02-04 10:06:55.392595: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-04 10:06:55.393634: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-04 10:06:55.430950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-04 10:06:55.431528: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# ...
